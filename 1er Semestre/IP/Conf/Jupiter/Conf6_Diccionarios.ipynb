# %% [markdown]
# # Conf 6 DICCIONARIOS. ARCHIVOS JSON
#
# Los elementos de una lista pueden ser accedidos y modificados (por eso se dice que las listas son mutables), posicionalmente a través de un **índice**
#
# Si `l` es una variable cuyo valor es una lista `l[k]` denota el elemento en la posición `k`. `k `tiene que ser un valor entre `0 `y la cantidad de elementos de la lista `len(l)-1`. Aunque usualmente los elementos de una lista son de un mismo tipo, loa valores de una lista pueden ser de cualquier tipo.
#
# Una característica importante de las listas es que independientemente del valor de k el acceso al elemento l[k] siempre demora un tiempo fijo. Esto permite predecir el tiempo que. en dependencia de la cantidad n de elementos en la lista, puede demorar el procesamiento que se haga con los mismos.
#
# Al igual que las listas los **diccionarios** son estructuras de datos formadas por varios datos. Los diccionarios pueden verse como colecciones de pares de datos que suelen denominarse _llave_ (_key_) y _valor_ (_value_). Si `d` tiene como valor un diccionario entonces los valores en el diccionario puedes ser accedidos en la forma `d`[_llave_] que denotará al valor asociado a esa _llave_. El siguiente ejemplo nos ilustra un diccionario de contactos donde cada llave (en este caso una cadena con el nombre de la persona) tiene asociado un valor (en este ejemplo un entero con su número de teléfono)
#
# `contactos = { "juan":55053344, "maría":78332526, "casa":79326573 }`
#
# En este caso `contactos["maría"]` nos daría el valor `78332526`
#
# El diccionario no pone restricciones sobre qué se usa como _llave_ y sobre cuál es su `valor asociado`. Depende de lo que usted quiera representar con el diccionario. En este ejemplo las llaves siempre son `string` que expresan el *nombre de in contact*o y los valores son enteros que expresan _números de teléfono_
#
# La operación print escribe un diccionario en un formato predefinido pero usted puede acceder a sus componentes y escribirlo como le convenga como puede verse ejecutando el código a continuación
#
#
# ### 6.1 Operaciones sobre diccionarios

# %%
contactos = { "juan":55053344, "maría":78332526, "casa":79326573 }
print(contactos)

#Accediendo al telefono de maría
print(f'El teléfono de {"maría"} es {contactos["maría"]}')

#Cambiando el teléfono de casa
contactos["casa"] = 78324031
print(contactos)

#Añadiendo un nuevo contacto es similar a cambiar, si la llave no existe crea la entrada
contactos["pepe (carpintero)"] = 56062230
print(contactos)

#Escribiendo todos mis contactos
print(contactos.keys())
for s in contactos.keys():
    print(s)

#Escribiendo todos los pares contacto teléfono
print(contactos.items())
for x in contactos.items():
    print(x)

x = contactos["maría"]
print(x)
# Out:
# {'juan': 55053344, 'maría': 78332526, 'casa': 79326573}
# El teléfono de maría es 78332526
# {'juan': 55053344, 'maría': 78332526, 'casa': 78324031}
# {'juan': 55053344, 'maría': 78332526, 'casa': 78324031, 'pepe (carpintero)': 56062230}
# dict_keys(['juan', 'maría', 'casa', 'pepe (carpintero)'])
# juan
# maría
# casa
# pepe (carpintero)
# dict_items([('juan', 55053344), ('maría', 78332526), ('casa', 78324031), ('pepe (carpintero)', 56062230)])
# ('juan', 55053344)
# ('maría', 78332526)
# ('casa', 78324031)
# ('pepe (carpintero)', 56062230)
# 78332526

# %% [markdown]
# ## 6.2 Un diccionario para representar todos los datos de una entidad
# _Un diccionario es una estructura ideal para representar las diferentes características de una entidad_ (un **objeto**  que es como lo llamaremos mas adelante).
#
# Por ejemplo los datos de un _contacto_ se pueden representar con un diccionario
#
# `{ "nombre":"Juana Pérez Pérez", "telefonos":[55053344, 78304266], "direccion":"12 #333 e/21 y 19, Plaza", "email":"juanapp@gmail.com", "fecha_nac": "8/10/2000"}`
#
# No hay restricción sobre cuál puede ser el tipo del valor que se use como _llave_ (key) y el tipo del _valor_ (value) asociado a la llave. Es usual que se use como llave una cadena (string) porque nos ayuda a identificar un rasgo, una caraterística, una cualidad, como en el ejemplo anterior. Note en este ejemplo como el valor asociado a la llave `teléfonos` es una _lista de enteros_ con números de teléfono porque un contacto puede tener más de un teléfono
#
# Los datos de un film se pueden representar con un diccionario, por ejemplo
#
# `{
#     "titulo": "El padrino I",
#
#     "pais": ["Estados Unidos"],
#
#     "fecha": 1972,
#
#     "director": "Francis Ford Coppola",
#
#     "genero": ["Crimen", "Drama"],
#
#     "actores_principales": ["Marlon Brando", "Al Pacino", "James Caan"],
#
#     "imdb": 9.2
# }`
#
# Los pares llave-valor que hay en un diccionario `d` pueden ser accedidos a través de `d.items()` Python los representa como una estructura conocida como **tuplos** con la notación (_llave_, _valor_). Parecido a la notación utilizada para las listas peo con paréntesis `(` y `)` en lugar de corchetes `[` y `]`. Los tuplos se estudiarán con más detalle más adelante

# %%
# juana = { "nombre":"Juana Pérez Pérez", "telefonos":[55053344, 78304266], "direccion":"12 #333 e/21 y 19, Plaza", "email":"juanapp@gmail.com", "fecha_nac": "8/10/2000"}
# print(juana)
# print()

mi_favorito = \
{
    "titulo"  : "El padrino I",
    "pais"    : ["Estados Unidos"],
    "fecha"   : 1972,
    "director": "Francis Ford Coppola",
    "genero"  : ["Crimen", "Drama"],
    "actores" : ["Marlon Brando", "Al Pacino", "James Caan"],
    "imdb"    : 9.2
}
print(mi_favorito)
print()

#Note al ejecutar el print anterior que Python escribe todos los pares llave-valor de forma consecutiva
#Una forma más legible de escribir esto puede ser

print("{")
for llave, valor in mi_favorito.items(): #el valor de un tuplo item del diccionario es desagregado en las variables llave y valor
    print(f"  {llave}: {valor}")
print("}")
print()

print(mi_favorito.keys())
print(mi_favorito.values())
print(mi_favorito.items())
# Out:
# {'titulo': 'El padrino I', 'pais': ['Estados Unidos'], 'fecha': 1972, 'director': 'Francis Ford Coppola', 'genero': ['Crimen', 'Drama'], 'actores': ['Marlon Brando', 'Al Pacino', 'James Caan'], 'imdb': 9.2}
#
# {
#   titulo: El padrino I
#   pais: ['Estados Unidos']
#   fecha: 1972
#   director: Francis Ford Coppola
#   genero: ['Crimen', 'Drama']
#   actores: ['Marlon Brando', 'Al Pacino', 'James Caan']
#   imdb: 9.2
# }
#
# dict_keys(['titulo', 'pais', 'fecha', 'director', 'genero', 'actores', 'imdb'])
# dict_values(['El padrino I', ['Estados Unidos'], 1972, 'Francis Ford Coppola', ['Crimen', 'Drama'], ['Marlon Brando', 'Al Pacino', 'James Caan'], 9.2])
# dict_items([('titulo', 'El padrino I'), ('pais', ['Estados Unidos']), ('fecha', 1972), ('director', 'Francis Ford Coppola'), ('genero', ['Crimen', 'Drama']), ('actores', ['Marlon Brando', 'Al Pacino', 'James Caan']), ('imdb', 9.2)])

# %% [markdown]
# ## 6.3 Archivos JSON
#
# Un archivo JSON es un formato de texto ligero para el intercambio de datos, es fácil e intuitivo de leer y escribir para los humanos, y a la vez sencillo de analizar e interpretar por los programas. En nuestro caso por un código Python.
#
# JSON son las siglas de "JavaScript Object Notation" (Notación de Objetos de JavaScript). Aunque proviene de la notación literal de objetos en JavaScript, JSON es independiente del lenguaje de programación y es muy utilizado en las aplicaciones de Python para leer y escribir datos estructurados.
#
# Un archivo JSON se puede escribir con cualquier aplicación que produzca texto, como el simple Bloq de Notas (NotePad). En forma similar a Python una lista de enteros se puede expresar por un _texto_ que empieza con `[` seguido de _textos_ separados por un _delimitador_ (usaremos coma `, `por defecto) hasta terminar con un `]`
#
# Para leer el archivo .json la aplicación Python solo tiene que indicar la _ruta_ donde se encuentra el archivo en el sistema y descargarlo con la operación `load`
#
# Usted tiene ahora en sus manos de escribir con comodidad sus datos de prueba sin tener que estarlos escribiendo explícitamente dentro del código Python
#
# ### 6.3.1 Lectura de una lista de enteros
#
# El código a continuación lee un archivo `enteros.json` que acompaña a este proyecto contiene una lista de enteros. Pruebe a visualizarla con su Notepad

# %%
import json
#
# Abrir un archivo JSON.
with open("C:\\Users\\Administrador\\Desktop\\CD\\repos\\CD 1er año\\IP\\Conf\\enteros for conf6.json", "r") as f: #Indicar la ruta donde se encuentra el archivo

# Otra opción
# with open("enteros.json", "r") as f:
#     #Por defecto si no se indica la ruta Python sobreentiende que está en la misma carpeta que el proyecto
#     # Escribir la lista en formato JSON dentro del archivo

    lista = json.load(f)
    print(lista)
    print()
# Out:
# [123, 456, 789, 4, 56, 78, 990, 238, 567, 345, 12, 6, 789, 234, 456, 678, 901, 234, 567, 890, 345, 123, 456, 678, 123, 456, 789, 234, 567, 234, 678, 90, 123, 456, 789, 23, 456, 678, 910, 234, 567, 12, 45, 789, 234, 567, 89, 123, 456, 789, 234, 567, 89, 123, 456, 789, 234, 56, 78, 90, 34, 56, 78, 90, 345, 123, 456, 789, 234, 567, 890, 234, 567, 890, 345, 123, 456, 789, 234, 56, 78, 90, 34, 56, 78, 90, 34, 56, 78, 90, 123, 456, 789, 234, 567, 901, 234, 567, 890, 345, 123, 456, 789, 847, 309, 932, 144, 553, 78, 432, 590, 682, 210, 34, 928, 675, 109, 255, 764, 364, 488, 919, 152, 41, 880, 773, 228, 503, 611, 124, 367, 315, 776, 621, 431, 654, 91, 660, 997, 823, 289, 554, 119, 378, 651, 456, 796, 682, 206, 554, 901, 253, 270, 590, 834, 61, 367, 518, 799, 253, 69, 487, 757, 874, 117, 39, 518, 624, 935, 111, 353, 993, 795, 426, 729, 510, 180, 825, 425, 721, 680, 157, 308, 415, 390, 785, 661, 621, 39, 234, 987, 120, 437, 684, 466, 895, 213, 578, 389, 244, 831, 515, 709, 948, 134, 567, 890, 234, 567, 812, 324, 609, 741, 280, 374, 513, 678, 345, 912, 430, 378, 665, 728, 148, 209, 367, 425, 512, 689, 732, 594, 210, 467, 589, 716, 345, 203, 625, 483, 712, 481, 342, 564, 719, 387, 654, 203, 756, 489, 321, 597, 846, 273, 528, 329, 615, 788, 242, 589, 683, 412, 796, 521, 338, 770, 439, 598, 765, 430, 725, 679, 384, 295, 715, 405, 638, 764, 298, 512, 682, 435, 796, 521, 692, 394, 278, 461, 799, 345, 527, 681, 423, 785, 538, 412, 679, 731, 495, 743, 351, 208, 679, 514]

# %% [markdown]
# ### 6.3.2 Lectura de una lista de diccionarios
#
# El ejemplo a continuación lee un archivo json que contiene una lista de diccionarios.
#
# Un dicionario se escribe en un texto json con una notación muy similar a la que se escribe en código Python.
#
# El archivo `MKM_Films.json` contiene una lista de diccionarios donde todos los diccionarios son similares y representan los datos de diferentes films. La lista es leida hacia la variable `films` que luego mandamos a escribir
#
# `print` escribe por defecto todos los valores de la lista seguidos y separados por coma, a su vez como cada elemento de la lista es un diccionario escribe seguidos todos los pares _llave-valor_ del diccionario.
#
# Como Ud puede comprobar que esto no es muy legible. Pero tenemos en nuestras manos la forma de hacerlo a nuestro gusto como nos muestra el segundo trozo de código

# %%
import json
with open("MKM_Films for conf6.json", "r") as f:
    films = json.load(f)

#Diferentes acciones con films. Ir descomentando y probando

#print("MKM_Films tal y como lo escribe print")
#print(films)
#print()

#print("MKM_FILMS. Llave y valor en cada linea")
#for film in films:
#    for llave, valor in film.items():
#        print(f"{llave}: {valor}")
#    print("-----------------\n")

print("MKM_FILMS Ordenados por título")
for film in sorted(films, key=lambda x: x['titulo']): # sorted ordena, lambda es la abreviatura de def por cada elemento cojes el titulo
    for llave, valor in film.items():
        print(f"{llave}: {valor}")
    print("-----------------\n")

# print("MKM_FILMS Ordenados por mejor evaluacion")
# for film in sorted(films, key=lambda x: x['imdb'], reverse=True): # sorted ordena de menor a mayor con reverse=True cambia de mayor a menor
#     for llave, valor in film.items():
#         print(f"{llave}: {valor}")
#     print("-----------------\n")
# Out:
# MKM_FILMS Ordenados por título
# titulo: 12 Years a Slave
# pais: ['Reino Unido', 'Estados Unidos']
# fecha: 2013
# director: Steve McQueen
# genero: ['BiografÃ\xada', 'Drama', 'Historia']
# actores_principales: ['Chiwetel Ejiofor', 'Michael Fassbender', "Lupita Nyong'o"]
# imdb: 8.1
# -----------------
#
# titulo: 15:17 Tren a Paris
# pais: ['Estados Unidos']
# fecha: 2018
# director: Clint Eastwood
# genero: ['Drama', 'Biografia', 'Thriller']
# actores_principales: ['Spencer Stone', 'Anthony Sadler', 'Aleksandr Kher']
# imdb: 6.3
# -----------------
#
# titulo: Amelie
# pais: ['Francia', 'Alemania']
# fecha: 2001
# director: Jean-Pierre Jeunet
# genero: ['Comedia', 'Romance']
# actores_principales: ['Audrey Tautou', 'Mathieu Kassovitz', 'Rufus']
# imdb: 8.3
# -----------------
#
# titulo: American History X
# pais: ['Estados Unidos']
# fecha: 1998
# director: Tony Kaye
# genero: ['Crimen', 'Drama']
# actores_principales: ['Edward Norton', 'Edward Furlong', "Beverly D'Angelo"]
# imdb: 8.5
# -----------------
#
# titulo: Argo
# pais: ['Estados Unidos', 'Reino Unido']
# fecha: 2012
# director: Ben Affleck
# genero: ['BiografÃ\xada', 'Drama', 'Thriller']
# actores_principales: ['Ben Affleck', 'Bryan Cranston', 'John Goodman']
# imdb: 7.7
# -----------------
#
# titulo: Birdman
# pais: ['Estados Unidos', 'MÃ©xico']
# fecha: 2014
# director: Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# genero: ['Comedia', 'Drama']
# actores_principales: ['Michael Keaton', 'Emma Stone', 'Edward Norton']
# imdb: 7.7
# -----------------
#
# titulo: Blade Runner 2049
# pais: ['Estados Unidos', 'Reino Unido', 'Canada']
# fecha: 2017
# director: Denis Villeneuve
# genero: ['Ciencia ficcion', 'Drama', 'Misterio']
# actores_principales: ['Ryan Gosling', 'Harrison Ford', 'Ana de Armas']
# imdb: 8.0
# -----------------
#
# titulo: CODA
# pais: ['Estados Unidos', 'CanadÃ¡', 'Francia']
# fecha: 2022
# director: Sian Heder
# genero: ['Drama']
# actores_principales: ['Emilia Jones', 'Marlee Matlin', 'Troy Kotsur']
# imdb: 8.0
# -----------------
#
# titulo: Cadena perpetua
# pais: ['Estados Unidos']
# fecha: 1994
# director: Frank Darabont
# genero: ['Drama']
# actores_principales: ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# imdb: 9.3
# -----------------
#
# titulo: Casablanca
# pais: ['Estados Unidos']
# fecha: 1942
# director: Michael Curtiz
# genero: ['Drama', 'Romance', 'Guerra']
# actores_principales: ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid']
# imdb: 8.5
# -----------------
#
# titulo: Casablanca
# pais: ['Estados Unidos']
# fecha: 1942
# director: Michael Curtiz
# genero: ['Drama', 'Romance', 'Guerra']
# actores_principales: ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid']
# imdb: 8.5
# -----------------
#
# titulo: Casino
# pais: ['Estados Unidos']
# fecha: 1995
# director: Martin Scorsese
# genero: ['Crimen', 'Drama']
# actores_principales: ['Robert De Niro', 'Sharon Stone', 'Joe Pesci']
# imdb: 8.2
# -----------------
#
# titulo: Cinema Paradiso
# pais: ['Italia', 'Francia']
# fecha: 1988
# director: Giuseppe Tornatore
# genero: ['Drama']
# actores_principales: ['Philippe Noiret', 'Enzo Cannavale', 'Antonella Attili']
# imdb: 8.5
# -----------------
#
# titulo: Ciudad de Dios
# pais: ['Brasil', 'Francia']
# fecha: 2002
# director: ['Fernando Meirelles', 'Katia Lund']
# genero: ['Crimen', 'Drama']
# actores_principales: ['Alexandre Rodrigues', 'Leandro Firmino', 'Matheus Nachtergaele']
# imdb: 8.6
# -----------------
#
# titulo: Coco
# pais: ['Estados Unidos']
# fecha: 2017
# director: ['Lee Unkrich', 'Adrian Molina']
# genero: ['Animacion', 'Aventura', 'Familia']
# actores_principales: ['Anthony Gonzalez', 'Gael Garcia Bernal', 'Benjamin Bratt']
# imdb: 8.4
# -----------------
#
# titulo: Cry Macho
# pais: ['Estados Unidos']
# fecha: 2021
# director: Clint Eastwood
# genero: ['Drama']
# actores_principales: ['Clint Eastwood', 'Dwight Yoakam']
# imdb: 6.0
# -----------------
#
# titulo: Donnie Brasco
# pais: ['Estados Unidos']
# fecha: 1997
# director: Mike Newell
# genero: ['Biografia', 'Crimen', 'Drama']
# actores_principales: ['Al Pacino', 'Johnny Depp']
# imdb: 7.7
# -----------------
#
# titulo: Dunkerque
# pais: ['Reino Unido', 'Francia', 'Paises Bajos', 'Estados Unidos']
# fecha: 2017
# director: Christopher Nolan
# genero: ['Drama', 'Historia', 'Guerra']
# actores_principales: ['Fionn Whitehead', 'Barry Keoghan', 'Mark Rylance']
# imdb: 7.9
# -----------------
#
# titulo: El Padrino II
# pais: ['Estados Unidos']
# fecha: 1974
# director: Francis Ford Coppola
# genero: ['Crimen', 'Drama']
# actores_principales: ['Al Pacino', 'Robert De Niro']
# imdb: 9.0
# -----------------
#
# titulo: El Padrino III
# pais: ['Estados Unidos']
# fecha: 1990
# director: Francis Ford Coppola
# genero: ['Drama', 'Mafia', 'Crimen', 'Familia']
# actores_principales: ['Al Pacino', 'Diane Keaton', 'Talia Shire', 'Andy GarcÃ\xada']
# imdb: 7.6
# -----------------
#
# titulo: El apartamento
# pais: ['Estados Unidos']
# fecha: 1960
# director: Billy Wilder
# genero: ['Comedia', 'Drama', 'Romance']
# actores_principales: ['Jack Lemmon', 'Shirley MacLaine', 'Fred MacMurray']
# imdb: 8.3
# -----------------
#
# titulo: El aviador
# pais: ['Estados Unidos']
# fecha: 2004
# director: Martin Scorsese
# genero: ['Biografia', 'Drama']
# actores_principales: ['Leonardo DiCaprio']
# imdb: 7.5
# -----------------
#
# titulo: El bueno, el feo y el malo
# pais: ['Italia', 'EspaÃ±a']
# fecha: 1966
# director: Sergio Leone
# genero: ['Western']
# actores_principales: ['Clint Eastwood', 'Eli Wallach', 'Lee Van Cleef']
# imdb: 8.8
# -----------------
#
# titulo: El club de la lucha
# pais: ['Estados Unidos']
# fecha: 1999
# director: David Fincher
# genero: ['Drama']
# actores_principales: ['Brad Pitt', 'Edward Norton', 'Helena Bonham Carter']
# imdb: 8.8
# -----------------
#
# titulo: El club de los poetas muertos
# pais: ['Estados Unidos']
# fecha: 1989
# director: Peter Weir
# genero: ['Comedia', 'Drama']
# actores_principales: ['Robin Williams', 'Robert Sean Leonard', 'Ethan Hawke']
# imdb: 8.1
# -----------------
#
# titulo: El curioso caso de Benjamin Button
# pais: ['Estados Unidos']
# fecha: 2008
# director: David Fincher
# genero: ['Drama', 'Fantasia', 'Romance']
# actores_principales: ['Brad Pitt', 'Cate Blanchett', 'Tilda Swinton']
# imdb: 7.8
# -----------------
#
# titulo: El francotirador
# pais: ['Estados Unidos']
# fecha: 2014
# director: Clint Eastwood
# genero: ['Biografia', 'Drama', 'Guerra']
# actores_principales: ['Bradley Cooper', 'Sienna Miller', 'Jake McDorman']
# imdb: 7.3
# -----------------
#
# titulo: El gran Lebowski
# pais: ['Estados Unidos']
# fecha: 1998
# director: ['Joel Coen', 'Ethan Coen']
# genero: ['Comedia', 'Crimen']
# actores_principales: ['Jeff Bridges', 'John Goodman', 'Julianne Moore']
# imdb: 8.1
# -----------------
#
# titulo: El gran dictador
# pais: ['Estados Unidos']
# fecha: 1940
# director: Charles Chaplin
# genero: ['Comedia', 'Drama', 'Belico']
# actores_principales: ['Charles Chaplin', 'Paulette Goddard', 'Jack Oakie']
# imdb: 8.4
# -----------------
#
# titulo: El gran hotel Budapest
# pais: ['Estados Unidos', 'Alemania', 'Reino Unido']
# fecha: 2014
# director: Wes Anderson
# genero: ['Aventura', 'Comedia', 'Crimen']
# actores_principales: ['Ralph Fiennes', 'F. Murray Abraham', 'Mathieu Amalric']
# imdb: 8.1
# -----------------
#
# titulo: El indomable Will Hunting
# pais: ['Estados Unidos']
# fecha: 1997
# director: Gus Van Sant
# genero: ['Drama', 'Romance']
# actores_principales: ['Matt Damon', 'Robin Williams', 'Ben Affleck']
# imdb: 8.3
# -----------------
#
# titulo: El laberinto del fauno
# pais: ['Mexico', 'EspaÃ±a', 'Estados Unidos']
# fecha: 2006
# director: Guillermo del Toro
# genero: ['Drama', 'Fantasia', 'Guerra']
# actores_principales: ['Ivana Baquero', 'Ariadna Gil', 'Sergi Lopez']
# imdb: 8.2
# -----------------
#
# titulo: El lobo de Wall Street
# pais: ['Estados Unidos']
# fecha: 2013
# director: Martin Scorsese
# genero: ['Biografia', 'Comedia', 'Crimen']
# actores_principales: ['Leonardo DiCaprio', 'Jonah Hill', 'Margot Robbie']
# imdb: 8.2
# -----------------
#
# titulo: El maquinista
# pais: ['EspaÃ±a']
# fecha: 2004
# director: Brad Anderson
# genero: ['Drama', 'Misterio', 'Thriller']
# actores_principales: ['Christian Bale', 'Jennifer Jason Leigh', 'Aitana Sanchez-Gijon']
# imdb: 7.7
# -----------------
#
# titulo: El mÃ©todo
# pais: ['EspaÃ±a', 'Argentina', 'Francia']
# fecha: 2005
# director: Marcelo PiÃ±eyro
# genero: ['Thriller', 'Drama']
# actores_principales: ['Eduardo Noriega', 'Najwa Nimri']
# imdb: 7.1
# -----------------
#
# titulo: El padrino I
# pais: ['Estados Unidos']
# fecha: 1972
# director: Francis Ford Coppola
# genero: ['Crimen', 'Drama']
# actores_principales: ['Marlon Brando', 'Al Pacino', 'James Caan']
# imdb: 9.2
# -----------------
#
# titulo: El pianista
# pais: ['Francia', 'Polonia', 'Alemania', 'Reino Unido']
# fecha: 2002
# director: Roman Polanski
# genero: ['Biografia', 'Drama', 'Musica']
# actores_principales: ['Adrien Brody', 'Thomas Kretschmann', 'Frank Finlay']
# imdb: 8.5
# -----------------
#
# titulo: El precio del poder (Scarface)
# pais: ['Estados Unidos']
# fecha: 1983
# director: Brian De Palma
# genero: ['Crimen', 'Drama', 'Suspenso']
# actores_principales: ['Al Pacino']
# imdb: 8.3
# -----------------
#
# titulo: El renacido
# pais: ['Estados Unidos']
# fecha: 2015
# director: Alejandro Gonzalez IÃ±arritu
# genero: ['Aventura', 'Drama', 'Western']
# actores_principales: ['Leonardo DiCaprio', 'Tom Hardy', 'Domhnall Gleeson']
# imdb: 8.0
# -----------------
#
# titulo: El resplandor
# pais: ['Reino Unido', 'Estados Unidos']
# fecha: 1980
# director: Stanley Kubrick
# genero: ['Drama', 'Terror']
# actores_principales: ['Jack Nicholson', 'Shelley Duvall', 'Danny Lloyd']
# imdb: 8.4
# -----------------
#
# titulo: El rey leon
# pais: ['Estados Unidos']
# fecha: 1994
# director: ['Roger Allers', 'Rob Minkoff']
# genero: ['Animacion', 'Aventura', 'Drama']
# actores_principales: ['Matthew Broderick', 'Jeremy Irons', 'James Earl Jones']
# imdb: 8.5
# -----------------
#
# titulo: El secreto de Brokeback Mountain
# pais: ['Estados Unidos']
# fecha: 2005
# director: Ang Lee
# genero: ['Drama', 'Romance', 'Western']
# actores_principales: ['Heath Ledger', 'Jake Gyllenhaal', 'Michelle Williams']
# imdb: 7.7
# -----------------
#
# titulo: El secreto de la montaÃ±a
# pais: ['Estados Unidos']
# fecha: 2005
# director: Ang Lee
# genero: ['Drama', 'Romance']
# actores_principales: ['Sean Penn', 'Michelle Pfeiffer', 'Jake Gyllenhaal']
# imdb: 7.9
# -----------------
#
# titulo: El secreto de sus ojos
# pais: ['Argentina', 'EspaÃ±a']
# fecha: 2009
# director: Juan Jose Campanella
# genero: ['Drama', 'Misterio', 'Romance']
# actores_principales: ['Ricardo Darin', 'Soledad Villamil', 'Pablo Rago']
# imdb: 8.2
# -----------------
#
# titulo: El sexto sentido
# pais: ['Estados Unidos']
# fecha: 1999
# director: M. Night Shyamalan
# genero: ['Drama', 'Misterio', 'Thriller']
# actores_principales: ['Bruce Willis', 'Haley Joel Osment', 'Toni Collette']
# imdb: 8.2
# -----------------
#
# titulo: El seÃ±or de los anillos: El retorno del rey
# pais: ['Nueva Zelanda', 'Estados Unidos']
# fecha: 2003
# director: Peter Jackson
# genero: ['Aventura', 'Drama', 'Fantasia']
# actores_principales: ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen']
# imdb: 9.0
# -----------------
#
# titulo: El show de Truman
# pais: ['Estados Unidos']
# fecha: 1998
# director: Peter Weir
# genero: ['Comedia', 'Drama', 'Ciencia ficcion']
# actores_principales: ['Jim Carrey', 'Ed Harris', 'Laura Linney']
# imdb: 8.2
# -----------------
#
# titulo: El viaje de Chihiro
# pais: ['Japon']
# fecha: 2001
# director: Hayao Miyazaki
# genero: ['Animacion', 'Aventura', 'Familia']
# actores_principales: ['Rumi Hiiragi', 'Miyu Irino', 'Mari Natsuki']
# imdb: 8.6
# -----------------
#
# titulo: En la linea de fuego
# pais: ['Estados Unidos']
# fecha: 1993
# director: Wolfgang Petersen
# genero: ['Accion', 'Suspense', 'Thriller']
# actores_principales: ['Clint Eastwood', 'John Malkovich']
# imdb: 7.2
# -----------------
#
# titulo: Escape from Alcatraz
# pais: ['Estados Unidos']
# fecha: 1979
# director: Don Siegel
# genero: ['Crimen', 'Drama', 'Thriller']
# actores_principales: ['Clint Eastwood']
# imdb: 7.6
# -----------------
#
# titulo: Forrest Gump
# pais: ['Estados Unidos']
# fecha: 1994
# director: Robert Zemeckis
# genero: ['Drama', 'Romance']
# actores_principales: ['Tom Hanks', 'Robin Wright', 'Gary Sinise']
# imdb: 8.8
# -----------------
#
# titulo: Gladiator
# pais: ['Estados Unidos', 'Reino Unido']
# fecha: 2000
# director: Ridley Scott
# genero: ['Accion', 'Aventura', 'Drama']
# actores_principales: ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen']
# imdb: 8.5
# -----------------
#
# titulo: Green Book
# pais: ['Estados Unidos']
# fecha: 2018
# director: Peter Farrelly
# genero: ['BiografÃ\xada', 'Comedia', 'Drama']
# actores_principales: ['Viggo Mortensen', 'Mahershala Ali']
# imdb: 8.2
# -----------------
#
# titulo: Harry el sucio
# pais: ['Estados Unidos']
# fecha: 1971
# director: Don Siegel
# genero: ['Accion', 'Crimen', 'Thriller']
# actores_principales: ['Clint Eastwood']
# imdb: 7.9
# -----------------
#
# titulo: Heat
# fecha: 1995
# director: Michael Mann
# genero: ['Crimen', 'Thriller', 'Accion']
# actores_principales: ['Al Pacino', 'Robert De Niro', 'Val Kilmer']
# imdb: 8.3
# -----------------
#
# titulo: Her
# pais: ['Estados Unidos']
# fecha: 2013
# director: Spike Jonze
# genero: ['Drama', 'Romance', 'Ciencia ficcion']
# actores_principales: ['Joaquin Phoenix', 'Amy Adams', 'Scarlett Johansson']
# imdb: 8.0
# -----------------
#
# titulo: Interstellar
# pais: ['Estados Unidos', 'Reino Unido', 'Canada']
# fecha: 2014
# director: Christopher Nolan
# genero: ['Aventura', 'Drama', 'Ciencia ficcion']
# actores_principales: ['Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain']
# imdb: 8.7
# -----------------
#
# titulo: Intocable
# pais: ['Francia']
# fecha: 2011
# director: ['Olivier Nakache', 'Eric Toledano']
# genero: ['Biografia', 'Comedia', 'Drama']
# actores_principales: ['FranÃ§ois Cluzet', 'Omar Sy', 'Anne Le Ny']
# imdb: 8.5
# -----------------
#
# titulo: J. Edgar
# pais: ['Estados Unidos']
# fecha: 2011
# director: Clint Eastwood
# genero: ['Biografia', 'Drama', 'Historia']
# actores_principales: ['Leonardo DiCaprio', 'Armie Hammer', 'Naomi Watts']
# imdb: 6.5
# -----------------
#
# titulo: Jersey Boys
# pais: ['Estados Unidos']
# fecha: 2014
# director: Clint Eastwood
# genero: ['Biografia', 'Drama', 'Musical']
# actores_principales: ['John Lloyd Young', 'Erich Bergen', 'Michael Lomenda']
# imdb: 6.6
# -----------------
#
# titulo: Joe Kidd
# pais: ['Estados Unidos']
# fecha: 1972
# director: John Sturges
# genero: ['Western', 'Accion']
# actores_principales: ['Clint Eastwood']
# imdb: 6.6
# -----------------
#
# titulo: Joker
# pais: ['Estados Unidos', 'Canada']
# fecha: 2019
# director: Todd Phillips
# genero: ['Crimen', 'Drama', 'Thriller']
# actores_principales: ['Joaquin Phoenix', 'Robert De Niro', 'Zazie Beetz']
# imdb: 8.4
# -----------------
#
# titulo: Jurado NÃºmero 2
# pais: ['Reino Unido', 'Estados Unidos']
# fecha: 2024
# director: Daniel Sackheim
# genero: ['Drama', 'Crimen']
# actores_principales: ['Toni Collette', 'Dakota Fanning', 'Michael Shannon']
# imdb: 7.0
# -----------------
#
# titulo: La Caza
# pais: ['Dinamarca', 'Suecia']
# fecha: 2012
# director: Thomas Vinterberg
# genero: ['Drama']
# actores_principales: ['Mads Mikkelsen', 'Thomas Bo Larsen', 'Annika Wedderkopp']
# imdb: 8.3
# -----------------
#
# titulo: La La Land
# pais: ['Estados Unidos']
# fecha: 2016
# director: Damien Chazelle
# genero: ['Comedia', 'Drama', 'Musica']
# actores_principales: ['Ryan Gosling', 'Emma Stone', 'Rosemarie DeWitt']
# imdb: 8.0
# -----------------
#
# titulo: La caza del Octubre Rojo
# pais: ['Estados Unidos']
# fecha: 1990
# director: John McTiernan
# genero: ['Accion', 'Aventura', 'Thriller']
# actores_principales: ['Sean Connery', 'Alec Baldwin', 'Scott Glenn']
# imdb: 7.6
# -----------------
#
# titulo: La gran belleza
# pais: ['Italia', 'Francia']
# fecha: 2013
# director: Paolo Sorrentino
# genero: ['Drama']
# actores_principales: ['Toni Servillo', 'Carlo Verdone', 'Sabrina Ferilli']
# imdb: 7.7
# -----------------
#
# titulo: La habitacion
# pais: ['Irlanda', 'Canada', 'Reino Unido', 'Estados Unidos']
# fecha: 2015
# director: Lenny Abrahamson
# genero: ['Drama', 'Thriller']
# actores_principales: ['Brie Larson', 'Jacob Tremblay', 'Sean Bridgers']
# imdb: 8.1
# -----------------
#
# titulo: La leyenda del indomable
# pais: ['Estados Unidos']
# fecha: 1967
# director: Stuart Rosenberg
# genero: ['Drama']
# actores_principales: ['Paul Newman', 'George Kennedy', 'Strother Martin']
# imdb: 8.1
# -----------------
#
# titulo: La lista de Schindler
# pais: ['Estados Unidos']
# fecha: 1993
# director: Steven Spielberg
# genero: ['Biografia', 'Drama', 'Historia']
# actores_principales: ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley']
# imdb: 9.0
# -----------------
#
# titulo: La llegada
# pais: ['Estados Unidos', 'Canada']
# fecha: 2016
# director: Denis Villeneuve
# genero: ['Drama', 'Misterio', 'Ciencia ficcion']
# actores_principales: ['Amy Adams', 'Jeremy Renner', 'Forest Whitaker']
# imdb: 7.9
# -----------------
#
# titulo: La milla verde
# pais: ['Estados Unidos']
# fecha: 1999
# director: Frank Darabont
# genero: ['Crimen', 'Drama', 'Fantasia']
# actores_principales: ['Tom Hanks', 'Michael Clarke Duncan', 'David Morse']
# imdb: 8.6
# -----------------
#
# titulo: La naranja mecanica
# pais: ['Reino Unido', 'Estados Unidos']
# fecha: 1971
# director: Stanley Kubrick
# genero: ['Crimen', 'Drama', 'Ciencia ficcion']
# actores_principales: ['Malcolm McDowell', 'Patrick Magee', 'Michael Bates']
# imdb: 8.3
# -----------------
#
# titulo: La princesa Mononoke
# pais: ['Japon']
# fecha: 1997
# director: Hayao Miyazaki
# genero: ['Animacion', 'Aventura', 'Fantasia']
# actores_principales: ['YÃ´ji Matsuda', 'Yuriko Ishida', 'YÃ»ko Tanaka']
# imdb: 8.4
# -----------------
#
# titulo: La tumba de las luciernagas
# pais: ['Japon']
# fecha: 1988
# director: Isao Takahata
# genero: ['Animacion', 'Drama', 'Guerra']
# actores_principales: ['Tsutomu Tatsumi', 'Ayano Shiraishi', 'Akemi Yamaguchi']
# imdb: 8.5
# -----------------
#
# titulo: La vida de los otros
# pais: ['Alemania']
# fecha: 2006
# director: Florian Henckel von Donnersmarck
# genero: ['Drama', 'Misterio', 'Thriller']
# actores_principales: ['Ulrich MÃ¼he', 'Martina Gedeck', 'Sebastian Koch']
# imdb: 8.4
# -----------------
#
# titulo: La vida es bella
# pais: ['Italia']
# fecha: 1997
# director: Roberto Benigni
# genero: ['Comedia', 'Drama', 'Romance']
# actores_principales: ['Roberto Benigni', 'Nicoletta Braschi', 'Giorgio Cantarini']
# imdb: 8.6
# -----------------
#
# titulo: Looking for Eric
# pais: ['Reino Unido', 'Francia']
# fecha: 2009
# director: Ken Loach
# genero: ['Comedia', 'Drama']
# actores_principales: ['Steve Evets', 'Ã‰ric Cantona']
# imdb: 7.1
# -----------------
#
# titulo: Los infiltrados
# pais: ['Estados Unidos']
# fecha: 2006
# director: Martin Scorsese
# genero: ['Crimen', 'Drama', 'Thriller']
# actores_principales: ['Leonardo DiCaprio', 'Matt Damon', 'Jack Nicholson']
# imdb: 8.5
# -----------------
#
# titulo: Los odiosos ocho
# pais: ['Estados Unidos']
# fecha: 2015
# director: Quentin Tarantino
# genero: ['Crimen', 'Drama', 'Misterio']
# actores_principales: ['Samuel L. Jackson', 'Kurt Russell', 'Jennifer Jason Leigh']
# imdb: 7.8
# -----------------
#
# titulo: Mad Max: Furia en la carretera
# pais: ['Australia', 'Estados Unidos']
# fecha: 2015
# director: George Miller
# genero: ['Accion', 'Aventura', 'Ciencia ficcion']
# actores_principales: ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult']
# imdb: 8.1
# -----------------
#
# titulo: Magnum Force
# pais: ['Estados Unidos']
# fecha: 1973
# director: Ted Post
# genero: ['Accion', 'Crimen', 'Suspense']
# actores_principales: ['Clint Eastwood']
# imdb: 7.1
# -----------------
#
# titulo: Mas alla de la vida
# pais: ['Estados Unidos']
# fecha: 2010
# director: Clint Eastwood
# genero: ['Drama', 'Fantastico', 'Romantico']
# actores_principales: ['Matt Damon', 'Cecile de France', 'Bryan Cranston']
# imdb: 6.5
# -----------------
#
# titulo: Memento
# pais: ['Estados Unidos']
# fecha: 2000
# director: Christopher Nolan
# genero: ['Misterio', 'Thriller']
# actores_principales: ['Guy Pearce', 'Carrie-Anne Moss', 'Joe Pantoliano']
# imdb: 8.4
# -----------------
#
# titulo: Mula
# pais: ['Estados Unidos']
# fecha: 2018
# director: Clint Eastwood
# genero: ['Crimen', 'Drama', 'Thriller']
# actores_principales: ['Clint Eastwood', 'Bradley Cooper', 'Laurence Fishburne']
# imdb: 7.0
# -----------------
#
# titulo: Nomadland
# pais: ['Estados Unidos']
# fecha: 2020
# director: ChloÃ© Zhao
# genero: ['Drama']
# actores_principales: ['Frances McDormand', 'David Strathairn']
# imdb: 7.4
# -----------------
#
# titulo: Oldboy
# pais: ['Corea del Sur']
# fecha: 2003
# director: Park Chan-wook
# genero: ['Accion', 'Drama', 'Misterio']
# actores_principales: ['Choi Min-sik', 'Yoo Ji-tae', 'Kang Hye-jeong']
# imdb: 8.4
# -----------------
#
# titulo: Origen
# pais: ['Estados Unidos', 'Reino Unido']
# fecha: 2010
# director: Christopher Nolan
# genero: ['Accion', 'Aventura', 'Ciencia ficcion']
# actores_principales: ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page']
# imdb: 8.8
# -----------------
#
# titulo: Parasite
# pais: ['Corea del Sur']
# fecha: 2019
# director: Bong Joon-ho
# genero: ['Thriller', 'Drama']
# actores_principales: ['Song Kang-ho', 'Lee Sun-kyun', 'Cho Yeo-jeong']
# imdb: 8.6
# -----------------
#
# titulo: Parasitos
# pais: ['Corea del Sur']
# fecha: 2019
# director: Bong Joon-ho
# genero: ['Comedia', 'Drama', 'Thriller']
# actores_principales: ['Kang-ho Song', 'Sun-kyun Lee', 'Yeo-jeong Jo']
# imdb: 8.5
# -----------------
#
# titulo: Perdida
# pais: ['Estados Unidos']
# fecha: 2014
# director: David Fincher
# genero: ['Drama', 'Misterio', 'Thriller']
# actores_principales: ['Ben Affleck', 'Rosamund Pike', 'Neil Patrick Harris']
# imdb: 8.1
# -----------------
#
# titulo: Psicosis
# pais: ['Estados Unidos']
# fecha: 1960
# director: Alfred Hitchcock
# genero: ['Terror', 'Misterio', 'Thriller']
# actores_principales: ['Anthony Perkins', 'Janet Leigh', 'Vera Miles']
# imdb: 8.5
# -----------------
#
# titulo: Pulp Fiction
# pais: ['Estados Unidos']
# fecha: 1994
# director: Quentin Tarantino
# genero: ['Crimen', 'Drama']
# actores_principales: ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson']
# imdb: 8.9
# -----------------
#
# titulo: Requiem por un sueÃ±o
# pais: ['Estados Unidos']
# fecha: 2000
# director: Darren Aronofsky
# genero: ['Drama']
# actores_principales: ['Ellen Burstyn', 'Jared Leto', 'Jennifer Connelly']
# imdb: 8.3
# -----------------
#
# titulo: Retrato de una mujer en llamas
# pais: ['Francia', 'Irlanda']
# fecha: 2019
# director: CÃ©line Sciamma
# genero: ['Drama', 'Romance']
# actores_principales: ['NoÃ©mie Merlant', 'AdÃ¨le Haenel']
# imdb: 7.9
# -----------------
#
# titulo: Richard Jewell
# pais: ['Estados Unidos']
# fecha: 2019
# director: Clint Eastwood
# genero: ['Biografia', 'Drama', 'Thriller']
# actores_principales: ['Paul Walter Hauser', 'Sam Rockwell', 'Kathy Bates']
# imdb: 7.4
# -----------------
#
# titulo: Spotlight
# pais: ['Estados Unidos']
# fecha: 2015
# director: Tom McCarthy
# genero: ['BiografÃ\xada', 'Crimen', 'Drama']
# actores_principales: ['Mark Ruffalo', 'Michael Keaton', 'Rachel McAdams']
# imdb: 8.1
# -----------------
#
# titulo: Sully
# pais: ['Estados Unidos']
# fecha: 2016
# director: Clint Eastwood
# genero: ['Biografia', 'Drama']
# actores_principales: ['Tom Hanks', 'Aaron Eckhart', 'Laura Linney']
# imdb: 7.4
# -----------------
#
# titulo: Taxi Driver
# pais: ['Estados Unidos']
# fecha: 1976
# director: Martin Scorsese
# genero: ['Crimen', 'Drama']
# actores_principales: ['Robert De Niro', 'Jodie Foster', 'Harvey Keitel']
# imdb: 8.3
# -----------------
#
# titulo: The Shape of Water
# pais: ['Estados Unidos', 'CanadÃ¡', 'MÃ©xico']
# fecha: 2017
# director: Guillermo del Toro
# genero: ['Drama', 'Romance', 'FantasÃ\xada']
# actores_principales: ['Sally Hawkins', 'Michael Shannon', 'Doug Jones']
# imdb: 7.3
# -----------------
#
# titulo: Titanic
# pais: ['Estados Unidos']
# fecha: 1997
# director: James Cameron
# genero: ['Drama', 'Romance']
# actores_principales: ['Leonardo DiCaprio', 'Kate Winslet']
# imdb: 7.9
# -----------------
#
# titulo: Todo a la vez en todas partes
# pais: ['Estados Unidos']
# fecha: 2022
# director: Daniel Kwan, Daniel Scheinert
# genero: ['Comedia', 'Drama', 'Ciencia ficciÃ³n']
# actores_principales: ['Michelle Yeoh', 'Stephanie Hsu', 'Ke Huy Quan']
# imdb: 8.1
# -----------------
#
# titulo: V de Vendetta
# pais: ['Reino Unido', 'Alemania']
# fecha: 2005
# director: James McTeigue
# genero: ['Accion', 'Drama', 'Ciencia ficcion']
# actores_principales: ['Hugo Weaving', 'Natalie Portman', 'Rupert Graves']
# imdb: 8.2
# -----------------
#
# titulo: Whiplash
# pais: ['Estados Unidos']
# fecha: 2014
# director: Damien Chazelle
# genero: ['Drama', 'Musica']
# actores_principales: ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist']
# imdb: 8.5
# -----------------

# %% [markdown]
# ### 6.3.3 Accediendo a las componentes de un diccionario
#
# El código a continuación nos muestra cómo podemos hacer consultas a los datos. En este caso queremos listar solo los films que son de género crimen o thriller. Note que el ciclo más externo la variable `film` recorre todos los valores de la lista `films ` luego a su vez para cada `film` se hace `film["genero"]` que es a su vez una lista de `string` con todos los géneros de ese `film` por eso se puede hacer una operación como `"Thriller"` `in film` para preguntar por todos las películas que tienen `"Thriller"` como género

# %%
with open("MKM_Films for conf6.json", "r") as f:
    films = json.load(f)
print("Films de Crimen o Thriller\n")
for film in films:
    if "Thiller" in film["genero"] or "Crimen" in film["genero"]:
        print(f'{film["titulo"]}')
        print(f'{film["genero"]}')
        print("-----------------\n")
# Out:
# Films de Crimen o Thriller
#
# El padrino I
# ['Crimen', 'Drama']
# -----------------
#
# Pulp Fiction
# ['Crimen', 'Drama']
# -----------------
#
# Ciudad de Dios
# ['Crimen', 'Drama']
# -----------------
#
# La naranja mecanica
# ['Crimen', 'Drama', 'Ciencia ficcion']
# -----------------
#
# La milla verde
# ['Crimen', 'Drama', 'Fantasia']
# -----------------
#
# Joker
# ['Crimen', 'Drama', 'Thriller']
# -----------------
#
# American History X
# ['Crimen', 'Drama']
# -----------------
#
# El gran hotel Budapest
# ['Aventura', 'Comedia', 'Crimen']
# -----------------
#
# El lobo de Wall Street
# ['Biografia', 'Comedia', 'Crimen']
# -----------------
#
# El gran Lebowski
# ['Comedia', 'Crimen']
# -----------------
#
# Los odiosos ocho
# ['Crimen', 'Drama', 'Misterio']
# -----------------
#
# Los infiltrados
# ['Crimen', 'Drama', 'Thriller']
# -----------------
#
# Taxi Driver
# ['Crimen', 'Drama']
# -----------------
#
# Heat
# ['Crimen', 'Thriller', 'Accion']
# -----------------
#
# El Padrino II
# ['Crimen', 'Drama']
# -----------------
#
# El precio del poder (Scarface)
# ['Crimen', 'Drama', 'Suspenso']
# -----------------
#
# Casino
# ['Crimen', 'Drama']
# -----------------
#
# Donnie Brasco
# ['Biografia', 'Crimen', 'Drama']
# -----------------
#
# Mula
# ['Crimen', 'Drama', 'Thriller']
# -----------------
#
# Magnum Force
# ['Accion', 'Crimen', 'Suspense']
# -----------------
#
# Harry el sucio
# ['Accion', 'Crimen', 'Thriller']
# -----------------
#
# Escape from Alcatraz
# ['Crimen', 'Drama', 'Thriller']
# -----------------
#
# Jurado NÃºmero 2
# ['Drama', 'Crimen']
# -----------------
#
# Spotlight
# ['BiografÃ\xada', 'Crimen', 'Drama']
# -----------------
#
# El Padrino III
# ['Drama', 'Mafia', 'Crimen', 'Familia']
# -----------------

# %% [markdown]
# ## 6.4 EJERCICIOS PARA CP
#
# 1. Escriba un diccionario en que las llaves sean string (el nombre de un contacto) y los valores sean a su vez diccionarios con todos los datos del contacto
# 2. Escriba un código que dadas dos listas `llaves` y `valores` cree un diccionario tomando como llave un valor de la primera lista (`llaves`) y como valor asociado a la llave el valor en la posición correspondiente en la segunda lista (`valores`).
#
#      Si la lista `llaves` tuviese el valor `["chocolate", "fresa", "vainilla"] `y la lista `valores` fuera `["preferido", "paso", "si no hay otro"]` debemos obtener el diccionario
#
#     `{"chocolate":"preferido", "fresa":"paso", "vainilla":"si no hay otro"}`
#
#      Si la `llaves` tuviese mas elementos que la lista `valores` entonces se le debe asociar el valor `None` a las llaves por exceso. Por ejemplo si fuese `["chocolate", "fresa", "vainilla", "almendra"]` y `["preferido", "paso", "si no hay otro"] `el resultado debería ser entonces
#
#      `{"chocolate":"preferido", "fresa":"paso", "vainilla":"sino hay otro", "almendra":None}`
#
#       Pero si hay más valores que llaves forme el diccionario hasta donde lleguen las llaves y escriba algún mensaje advirtiendo lo sucedido.
#
# 3. Decida y programe qué hacer si en la lista `llaves` se repitiese alguna llave
# 4. Dada una lista de diccionarios escriba un código que produzca una lista con iguales diccionarios pero ordenadas por el valor de una determinada llave
# 5. Para una variable `parrafo` cuyo valor es texto (string) produzca un diccionario que cuente la cantidad de veces que se usa cada vocal
